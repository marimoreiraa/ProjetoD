# %% [markdown]
# # Importação de bibliotecas

# %%
import pandas as pd
import psycopg2
import csv

# %% [markdown]
# # Criação dos DFs Pandas

# %%
df_2015_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2015_1s.csv', sep = ';', encoding = 'utf-8')
df_2015_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2015_2s.csv', sep = ';', encoding = 'utf-8')
df_2016_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2016_1s.csv', sep = ';', encoding = 'utf-8')
df_2016_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2016_2s.csv', sep = ';', encoding = 'utf-8')
df_2017_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2017_1t.csv', sep = ';', encoding = 'utf-8')
df_2017_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2017_2t.csv', sep = ';', encoding = 'utf-8')
df_2017_3 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2017_3t.csv', sep = ';', encoding = 'utf-8')
df_2017_4 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2017_4t.csv', sep = ';', encoding = 'utf-8')
df_2018_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2018_1t.csv', sep = ';', encoding = 'utf-8')
df_2018_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2018_2t.csv', sep = ';', encoding = 'utf-8')
df_2018_3 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2018_3t.csv', sep = ';', encoding = 'utf-8')
df_2018_4 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2018_4t.csv', sep = ';', encoding = 'utf-8')
df_2019_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2019_1t.csv', sep = ';', encoding = 'utf-8')
df_2019_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2019_2t.csv', sep = ';', encoding = 'utf-8')
df_2019_3 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2019_3t.csv', sep = ';', encoding = 'utf-8')
df_2019_4 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2019_4t.csv', sep = ';', encoding = 'utf-8')
df_2020_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2020_1t.csv', sep = ';', encoding = 'utf-8')
df_2020_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2020_2t.csv', sep = ';', encoding = 'utf-8')
df_2020_3 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2020_3t.csv', sep = ';', encoding = 'utf-8')
df_2020_4 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2020_4t.csv', sep = ';', encoding = 'utf-8')
df_2021_1 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2021_1t.csv', sep = ';', encoding = 'utf-8')
df_2021_2 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2021_2t.csv', sep = ';', encoding = 'utf-8')
df_2021_3 = pd.read_csv('/Users/lucasuriarte/Desktop/DBs/Reclame_QtdeClientes_2021_3t.csv', sep = ';', encoding = 'utf-8')

# %%
df_2020_3

# %% [markdown]
# # Criação de listas

# %%
list_2015_1 = df_2015_1.values.tolist()
list_2015_2 = df_2015_2.values.tolist()
list_2016_1 = df_2016_1.values.tolist()
list_2016_2 = df_2016_2.values.tolist()
list_2017_1 = df_2017_1.values.tolist()
list_2017_2 = df_2017_2.values.tolist()
list_2017_3 = df_2017_3.values.tolist()
list_2017_4 = df_2017_4.values.tolist()
list_2018_1 = df_2018_1.values.tolist()
list_2018_2 = df_2018_2.values.tolist()
list_2018_3 = df_2018_3.values.tolist()
list_2018_4 = df_2018_4.values.tolist()
list_2019_1 = df_2019_1.values.tolist()
list_2019_2 = df_2019_2.values.tolist()
list_2019_3 = df_2019_3.values.tolist()
list_2019_4 = df_2019_4.values.tolist()
list_2020_1 = df_2020_1.values.tolist()
list_2020_2 = df_2020_2.values.tolist()
list_2020_3 = df_2020_3.values.tolist()
list_2020_4 = df_2020_4.values.tolist()
list_2021_1 = df_2021_1.values.tolist()
list_2021_2 = df_2021_2.values.tolist()
list_2021_3 = df_2021_3.values.tolist()

# %%
print(list_2017_1)
# Out:
# [[2017, '1∫', 'Menos de quatro milhıes de clientes', 'Conglomerado', ' ', 'ABC-BRASIL (conglomerado)', ' ', 0, 3, 4, 7, 15653, '14377', '3090', '2846'], [2017, '1∫', 'Menos de quatro milhıes de clientes', 'Conglomerado', ' ', 'AGIPLAN (conglomerado)', '50,22', 16, 42, 75, 133, 318590, '27202', '302079', '3257'], [2017, '1∫', 'Menos de quatro milhıes de clientes', 'Banco/financeira', '36321990', 'AGORACRED S/A SOCIEDADE DE CR…DITO, FINANCIAMENTO E INVESTIMENTO', ' ', 0, 0, 1, 1, 178402, ' ', '178402', ' '], [2017, '1∫', 'Menos de quatro milhıes de clientes', 'Conglomerado', ' ', 'ALFA (conglomerado)', '31,2', 15, 22, 34, 71, 480685, '268776', '213888', '0'], [2017, '1∫', 'Menos de quatro milhıes de clientes', 'Conglomerado', ' ', 'ANDBANK (conglomerado)', ' ', 0, 0, 2, 2, 6870, '1052', '5822', '89'], [2017, '1∫', 'Menos de quatro milhıes de clientes', 'Banco/financeira', '23862762', 'AVISTA S.A. CR…DITO, FINANCIAMENTO E INVESTIMENTO', ' ', 0, 0, 1, 1, 119163, ' ', '119163', ' '], [201
# ...

# %% [markdown]
# # Definindo o conector Postgre

# %%
class connector_postgres:
    host = "localhost"
    database = "BC_reclame_mig"
    user = "postgres"
    password = "#BrilhaLuquinha1988"

    def conectar(self):
        conn = psycopg2.connect(host=self.host,
                                database=self.database,
                                user=self.user,
                                password=self.password)
        cursor = conn.cursor()

        return conn, cursor

    def desconectar(self, conn, cursor):
        cursor.close()
        conn.commit()
        conn.close()

    def inserir(self, query):
        conn, cursor = self.conectar()
        cursor.execute(query)
        self.desconectar(conn, cursor)

    def selecionar(self, query):
        conn, cursor = self.conectar()
        cursor.execute(query)
        lista = []
        for result in cursor.fetchall():
            lista.append(result)
        self.desconectar(conn, cursor)
        return lista

    def update(self, query):
        conn, cursor = self.conectar()
        cursor.execute(query)
        self.desconectar(conn, cursor)

    def delete(self, query):
        conn, cursor = self.conectar()
        cursor.execute(query)
        self.desconectar(conn, cursor)


conect = connector_postgres()

# %%
for i in list_2021_3:
    query = "INSERT INTO bc_reclame_2021_3 (ano, semestre, categoria, tipo, cnpj, instituicao_financeira, indice, qtde_rec_reg_proc, qtde_rec_reg_nao_proc, qtde_rec_nao_reg, qtde_total_rec, qtde_total_clientes, qtde_clientes_ccs, qtde_clientes_scr) VALUES('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}')".format(i[0], i[1], i[2], i[3], i[4], i[5], i[6], i[7], i[8], i[9], i[10], i[11], i[12], i[13])
    
    
    conect.inserir(query)
